# %%
import toml
from analysis import Analysis
#from analysis_syst import Analysis

# %%
cfg = """
[[this_includes]]
file = 'configurations/analyses/icarus/nue2025_icarus.toml'

[[this_includes]]
file = 'configurations/common/styles.toml'

[samples]
[samples.onbeam]
key = "onbeam"
exposure_type = "pot"
override_category = -100
trees = ['SelectedNu_PhaseCuts',]
#[samples.offbeam]
#key = "offbeam"
#exposure_type = "Livetime"
#override_category = -1
#trees = ['SelectedCos_PhaseCuts',]
[samples.mc_nu]
key = "mc"
exposure_type = "pot"
trees = ['SelectedNu_Cuts']
presel = 'matches_baseline == 1'
systematics = ['multisimTree']
print_sys = true
[samples.mc_cos]
key = "mc"
exposure_type = "pot"
trees = ['SelectedCos_PhaseCuts']
#presel = 'matches_baseline == 1'
#systematics = ['multisimTree']
#[samples.mc]
#key = "mc"
#exposure_type = "pot"
#trees = ['SelectedNu_Cuts','SelectedCos_PhaseCuts']



[output]
path = '/Users/danielcarber/Documents/ICARUS/NuMI_Nue/Plots'

[[systematic_recipe]]
name = 'flux'
label = 'Flux Systematics'
#pattern = '_Flux'
pattern = '\\b\\w*_Flux\\b'

[[systematic_recipe]]
name = 'xsec'
label = 'Interaction Systematics'
pattern = '\\bGENIEReWeight_SBN_v1_multisim_\\w+\\b'
#pattern = 'GENIEReWeight_SBN_v1_multisim'


[[systematic_recipe]]
name = 'stats'
label = 'Statistical Uncertainty'
#pattern = 'mc_statistical'
pattern = '(mc_nu|mc_cos)_statistical'
#pattern = '(mc|offbeam)_statistical'

#[[systematic_recipe]]
#name = 'offbeam_stats'
#label = 'Statistical Uncertainty'
#pattern = 'mc_statistical'
#pattern = '(mc_nu|mc_cos|offbeam)_statistical'
#pattern = '(offbeam)_statistical'

#[[systematic_recipe]]
#name = 'MC_stats'
#label = 'Statistical Uncertainty'
#pattern = 'mc_statistical'
#pattern = '(mc_nu|mc_cos)_statistical'
#pattern = '(offbeam)_statistical'

[[systematic_recipe]]
name = 'flux_xsec'
label = 'Flux + Interaction Uncertainty'
pattern = '(flux|xsec|stats)'
                
#[[systematic_recipe]]
#name = 'all'
#label = 'Total MC Uncertainty'
#pattern = '(flux|xsec|stats)'
#pattern = '(detsys|flux|xsec|stats)'


[analysis]
ordinate_sample = 'onbeam'
category_branch = 'category_topology'
category_assignment = [[0,1], [2,3,4,6], [5], [7],[8],[9],[11,-1], [-100]]
category_labels = ['1eNp', 'Other CC $\\nu_e$', 'NC $\\nu$', '$\\nu_\\mu$ CC','OOFVS','Other','Cosmic', 'Run 2 Data']
category_colors = ['C0', 'C1', 'C3', 'C4', 'C5','C6','C7','black']
category_types = ['histogram', 'histogram', 'histogram', 'histogram', 'histogram','histogram', 'histogram', 'scatter']


[[figure]]
name = 'reco_electron_energy'
type = 'SimpleFigure'
artists = [{'type' = 'SpineSpectra1D', 'variable' = 'reco_electron_energy'},]
style = 'selected_icarus'

[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_electron_energy'
range = [70, 3000]
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = true, 'draw_error' = 'flux_xsec'}

[[figure]]
name = 'reco_electron_pT_mag'
type = 'SimpleFigure'
artists = [{'type' = 'SpineSpectra1D', 'variable' = 'reco_electron_pT_mag'},]
style = 'selected_icarus'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_electron_pT_mag'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = true, 'draw_error' = 'flux_xsec'}

#[[figure]]
#name = 'reco_electron_conv_dist'
#type = 'SimpleFigure'
#artists = [{'type' = 'SpineSpectra1D', 'variable' = 'reco_electron_conv_dist'},]
#style = 'selected_icarus'
#[[figure.artists]]
#type = 'SpineSpectra1D'
#variable = 'reco_electron_conv_dist'
#draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = true, 'draw_error' = 'flux_xsec'}

[[figure]]
name = 'reco_electron_axial_spread'
type = 'SimpleFigure'
artists = [{'type' = 'SpineSpectra1D', 'variable' = 'reco_electron_axial_spread'},]
style = 'selected_icarus'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_electron_axial_spread'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = true, 'draw_error' = 'flux_xsec'}

[[figure]]
name = 'reco_electron_dir_spread'
type = 'SimpleFigure'
artists = [{'type' = 'SpineSpectra1D', 'variable' = 'reco_electron_dir_spread'},]
style = 'selected_icarus'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_electron_dir_spread'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = true, 'draw_error' = 'flux_xsec'}

[[figure]]
name = 'reco_proton_softmax'
type = 'SimpleFigure'
artists = [{'type' = 'SpineSpectra1D', 'variable' = 'reco_proton_softmax'},]
style = 'selected_icarus'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_proton_softmax'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = true, 'draw_error' = 'flux_xsec'}
[[figure]]
name = 'reco_dpT'
type = 'SimpleFigure'
artists = [{'type' = 'SpineSpectra1D', 'variable' = 'reco_dpT'},]
style = 'selected_icarus'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_dpT'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = true, 'draw_error' = 'flux_xsec'}
[[figure]]
name = 'reco_electron_softmax'
type = 'SimpleFigure'
artists = [{'type' = 'SpineSpectra1D', 'variable' = 'reco_electron_softmax'},]
style = 'selected_icarus'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_electron_softmax'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = true, 'draw_error' = 'flux_xsec'}

[[figure]]
name = 'reco_electron_dedx'
type = 'SimpleFigure'
artists = [{'type' = 'SpineSpectra1D', 'variable' = 'reco_electron_dedx'},]
style = 'selected_icarus'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_electron_dedx'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = true, 'draw_error' = 'flux_xsec'}

[[figure]]
name = 'reco_opening_angle'
type = 'SimpleFigure'
artists = [{'type' = 'SpineSpectra1D', 'variable' = 'reco_opening_angle'},]
style = 'selected_icarus'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_opening_angle'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = true, 'draw_error' = 'flux_xsec'}

[[figure]]
name = 'reco_dalphaT'
type = 'SimpleFigure'
artists = [{'type' = 'SpineSpectra1D', 'variable' = 'reco_dalphaT'},]
style = 'selected_icarus'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_dalphaT'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = true, 'draw_error' = 'flux_xsec'}

[[figure]]
name = 'reco_dphiT'
type = 'SimpleFigure'
artists = [{'type' = 'SpineSpectra1D', 'variable' = 'reco_dphiT'},]
style = 'selected_icarus'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_dphiT'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = true, 'draw_error' = 'flux_xsec'}

[[figure]]
name = 'reco_proton_energy'
type = 'SimpleFigure'
artists = [{'type' = 'SpineSpectra1D', 'variable' = 'reco_proton_energy'},]
style = 'selected_icarus'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_proton_energy'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = true, 'draw_error' = 'flux_xsec'}



"""
# Write the string to a file
with open('cfg.toml', 'w') as f:
    f.write(cfg)

file = '/Users/danielcarber/Documents/ICARUS/test_energy_syst.root'

analysis = Analysis('cfg.toml', file)
analysis.run(close_figs=False)
# Out:
# category_topology
# ['SelectedNu_PhaseCuts']
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 236
#     232     f.write(cfg)
#     234 file = '/Users/danielcarber/Documents/ICARUS/test_energy_syst.root'
# --> 236 analysis = Analysis('cfg.toml', file)
#     237 analysis.run(close_figs=False)
#
# File ~/Documents/ICARUS/NuMI_Nue/spine_anaplot_tools/spineplot/analysis.py:74, in Analysis.__init__(self, toml_path, rf_path)
#      72 if 'samples' not in self._config.keys():
#      73     raise ConfigException(f"No samples defined in the TOML file. Please check for a valid sample configuration block in the TOML file ('{toml_path}').")
# ---> 74 self._samples = {name: Sample(name, rf, self._config['analysis']['category_branch'], **self._config['samples'][name]) for name in self._config['samples']}
#      76 # Load the plot styles table
#      77 if 'style' not in self._config.keys():
#
# File ~/Documents/ICARUS/NuMI_Nue/spine_anaplot_tools/spineplot/analysis.py:74, in <dictcomp>(.0)
#      72 if 'samples' not in self._config.keys():
#      73     raise ConfigException(f"No samples defined in the TOML file. Please check for a valid sample configuration block in the TOML file ('{toml_path}').")
# ---> 74 self._samples = {name: Sample(name, rf, self._config['analysis']['category_branch'], **self._config['samples'][name]) for name in self._config['samples']}
#      76 # Load the plot styles table
#      77 if 'style' not in self._config.keys():
#
# File ~/Documents/ICARUS/NuMI_Nue/spine_anaplot_tools/spineplot/sample.py:95, in Sample.__init__(self, name, rf, category_branch, key, exposure_type, trees, systematics, override_exposure, precompute, presel, override_category, print_sys)
#      93     self.override_exposure(override_exposure, exposure_type)
#      94 print(trees)
# ---> 95 self._data = pd.concat([self._file_handle[tree].arrays(library='pd') for tree in trees])
#      96 if self._category_branch not in self._data.columns:
#      97     self._data[self._category_branch] = 0
#
# File ~/Documents/ICARUS/NuMI_Nue/spine_anaplot_tools/spineplot/sample.py:95, in <listcomp>(.0)
#      93     self.override_exposure(override_exposure, exposure_type)
#      94 print(trees)
# ---> 95 self._data = pd.concat([self._file_handle[tree].arrays(library='pd') for tree in trees])
#      96 if self._category_branch not in self._data.columns:
#      97     self._data[self._category_branch] = 0
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages/uproot/behaviors/TBranch.py:832, in HasBranches.arrays(self, expressions, cut, filter_name, filter_typename, filter_branch, aliases, language, entry_start, entry_stop, decompression_executor, interpretation_executor, array_cache, library, ak_add_doc, how)
#     827         if branch.cache_key not in checked:
#     828             checked.add(branch.cache_key)
#     829             for (
#     830                 basket_num,
#     831                 range_or_basket,
# --> 832             ) in branch.entries_to_ranges_or_baskets(entry_start, entry_stop):
#     833                 ranges_or_baskets.append((branch, basket_num, range_or_basket))
#     835 interp_options = {"ak_add_doc": ak_add_doc}
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages/uproot/behaviors/TBranch.py:2404, in TBranch.entries_to_ranges_or_baskets(self, entry_start, entry_stop)
#    2393 def entries_to_ranges_or_baskets(self, entry_start, entry_stop):
#    2394     """
#    2395     Returns a list of (start, stop) integer pairs for free (normal)
#    2396     ``TBaskets`` and :doc:`uproot.models.TBasket.Model_TBasket` objects
#    (...)
#    2402     read and interpreted.
#    2403     """
# -> 2404     entry_offsets = self.entry_offsets
#    2405     out = []
#    2406     start = entry_offsets[0]
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages/uproot/behaviors/TBranch.py:1987, in TBranch.entry_offsets(self)
#    1984     out = self.member("fBasketEntry")[: self._num_normal_baskets + 1].tolist()
#    1985 num_entries_normal = out[-1]
# -> 1987 for basket in self.embedded_baskets:
#    1988     out.append(out[-1] + basket.num_entries)
#    1990 if (
#    1991     out[-1] != self.num_entries
#    1992     and self.interpretation is not None
#    (...)
#    1995     )
#    1996 ):
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages/uproot/behaviors/TBranch.py:2378, in TBranch.embedded_baskets(self)
#    2372 """
#    2373 The ``TBaskets`` that are embedded within the ``TBranch`` metadata,
#    2374 usually because the ROOT process that was writing the file closed
#    2375 unexpectedly.
#    2376 """
#    2377 if self._embedded_baskets is None:
# -> 2378     cursor = self._cursor_baskets.copy()
#    2379     baskets = uproot.models.TObjArray.Model_TObjArrayOfTBaskets.read(
#    2380         self.tree.chunk, cursor, {}, self._file, self._file, self
#    2381     )
#    2382     with self._embedded_baskets_lock:
#
# AttributeError: 'Model_TBranchObject_v1' object has no attribute '_cursor_baskets'
