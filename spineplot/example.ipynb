# %%
import toml
from analysis import Analysis

# %%
cfg = """
[[this_includes]]
file = 'configurations/analyses/icarus/nue2025_icarus.toml'

[[this_includes]]
file = 'configurations/common/styles.toml'

[samples]
[samples.onbeam]
key = "onbeam"
exposure_type = "pot"
override_category = -100
trees = ['SelectedNu_PhaseCuts',]
[samples.offbeam]
key = "offbeam"
exposure_type = "Livetime"
override_category = -1
trees = ['SelectedCos_PhaseCuts',]
[samples.mc_nu]
key = "mc"
exposure_type = "pot"
trees = ['SelectedNu_Cuts']
presel = 'matches_baseline == 1'
systematics = ['multisimTree']
[samples.mc_cos]
key = "mc"
exposure_type = "pot"
trees = ['SelectedCos_PhaseCuts']
#presel = 'matches_baseline == 1'
#systematics = ['multisimTree']
#[samples.mc]
#key = "mc"
#exposure_type = "pot"
#trees = ['SelectedNu_Cuts','SelectedCos_PhaseCuts']



[output]
path = '/Users/danielcarber/Documents/ICARUS/NuMI_Nue/Plots'

[[systematic_recipe]]
name = 'flux'
label = 'Flux Systematics'
#pattern = '_Flux'
pattern = '\\b\\w*_Flux\\b'

[[systematic_recipe]]
name = 'xsec'
label = 'Interaction Systematics'
pattern = '\\bGENIEReWeight_SBN_v1_multisim_\\w+\\b'
#pattern = 'GENIEReWeight_SBN_v1_multisim'

[[systematic_recipe]]
name = 'minerva'
label = 'Interaction Systematics'
pattern = '\\bGENIEReWeight_SBN_v1_multisim_\\w+\\b'
#pattern = 'MINERvA'

[[systematic_recipe]]
name = 'stats'
label = 'Statistical Uncertainty'
#pattern = 'mc_statistical'
pattern = '(mc_nu|mc_cos|offbeam)_statistical'
#pattern = '(mc|offbeam)_statistical'

[[systematic_recipe]]
name = 'flux_xsec'
label = 'Flux + Interaction Uncertainty'
pattern = '(flux|xsec|stats)'
                
#[[systematic_recipe]]
#name = 'all'
#label = 'Total MC Uncertainty'
#pattern = '(flux|xsec|stats)'
#pattern = '(detsys|flux|xsec|stats)'


[analysis]
ordinate_sample = 'onbeam'
category_branch = 'category_topology'
category_assignment = [[0,1], [2,3,4,6], [5], [7],[8],[9],[10,-1], [-100]]
category_labels = ['1eNp', 'Other CC $\\nu_e$', 'NC $\\nu$', '$\\nu_\\mu$ CC','Uncontained','Other','Cosmic', 'Run 2 Data']
category_colors = ['C0', 'C1', 'C3', 'C4', 'C5','C6','C7','black']
category_types = ['histogram', 'histogram', 'histogram', 'histogram', 'histogram','histogram', 'histogram', 'scatter']


[[figure]]
name = 'reco_electron_energy'
type = 'SimpleFigure'
artists = [{'type' = 'SpineSpectra1D', 'variable' = 'reco_electron_energy'},]
style = 'selected_icarus'

[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_electron_energy'
range = [70, 3000]
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = true, 'draw_error' = 'flux_xsec'}

[[figure]]
name = 'reco_electron_pT_mag'
type = 'SimpleFigure'
artists = [{'type' = 'SpineSpectra1D', 'variable' = 'reco_electron_pT_mag'},]
style = 'selected_icarus'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_electron_pT_mag'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = true, 'draw_error' = 'flux_xsec'}

[[figure]]
name = 'reco_electron_conv_dist'
type = 'SimpleFigure'
artists = [{'type' = 'SpineSpectra1D', 'variable' = 'reco_electron_conv_dist'},]
style = 'selected_icarus'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_electron_conv_dist'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = true, 'draw_error' = 'flux_xsec'}

[[figure]]
name = 'reco_electron_axial_spread'
type = 'SimpleFigure'
artists = [{'type' = 'SpineSpectra1D', 'variable' = 'reco_electron_axial_spread'},]
style = 'selected_icarus'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_electron_axial_spread'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = true, 'draw_error' = 'flux_xsec'}

[[figure]]
name = 'reco_electron_dir_spread'
type = 'SimpleFigure'
artists = [{'type' = 'SpineSpectra1D', 'variable' = 'reco_electron_dir_spread'},]
style = 'selected_icarus'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_electron_dir_spread'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = true, 'draw_error' = 'flux_xsec'}

[[figure]]
name = 'reco_proton_softmax'
type = 'SimpleFigure'
artists = [{'type' = 'SpineSpectra1D', 'variable' = 'reco_proton_softmax'},]
style = 'selected_icarus'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_proton_softmax'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = true, 'draw_error' = 'flux_xsec'}
[[figure]]
name = 'reco_dpT'
type = 'SimpleFigure'
artists = [{'type' = 'SpineSpectra1D', 'variable' = 'reco_dpT'},]
style = 'selected_icarus'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_dpT'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = true, 'draw_error' = 'flux_xsec'}
[[figure]]
name = 'reco_electron_softmax'
type = 'SimpleFigure'
artists = [{'type' = 'SpineSpectra1D', 'variable' = 'reco_electron_softmax'},]
style = 'selected_icarus'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_electron_softmax'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = true, 'draw_error' = 'flux_xsec'}

[[figure]]
name = 'reco_electron_dedx'
type = 'SimpleFigure'
artists = [{'type' = 'SpineSpectra1D', 'variable' = 'reco_electron_dedx'},]
style = 'selected_icarus'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_electron_dedx'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = true, 'draw_error' = 'flux_xsec'}

[[figure]]
name = 'reco_opening_angle'
type = 'SimpleFigure'
artists = [{'type' = 'SpineSpectra1D', 'variable' = 'reco_opening_angle'},]
style = 'selected_icarus'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_opening_angle'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = true, 'draw_error' = 'flux_xsec'}

[[figure]]
name = 'reco_dalphaT'
type = 'SimpleFigure'
artists = [{'type' = 'SpineSpectra1D', 'variable' = 'reco_dalphaT'},]
style = 'selected_icarus'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_dalphaT'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = true, 'draw_error' = 'flux_xsec'}

[[figure]]
name = 'reco_dphiT'
type = 'SimpleFigure'
artists = [{'type' = 'SpineSpectra1D', 'variable' = 'reco_dphiT'},]
style = 'selected_icarus'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_dphiT'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = true, 'draw_error' = 'flux_xsec'}

[[figure]]
name = 'reco_NuMI_polar'
type = 'SimpleFigure'
artists = [{'type' = 'SpineSpectra1D', 'variable' = 'reco_NuMI_polar'},]
style = 'selected_icarus'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_NuMI_polar'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = true, 'draw_error' = 'flux_xsec'}

[[figure]]
name = 'reco_NuMI_azi'
type = 'SimpleFigure'
artists = [{'type' = 'SpineSpectra1D', 'variable' = 'reco_NuMI_azi'},]
style = 'selected_icarus'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_NuMI_azi'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = true, 'draw_error' = 'flux_xsec'}




"""
# Write the string to a file
with open('cfg.toml', 'w') as f:
    f.write(cfg)

file = '/Users/danielcarber/Documents/ICARUS/test_syst.root'

analysis = Analysis('cfg.toml', file)
analysis.run(close_figs=False)
# Out:
# /Users/danielcarber/Documents/ICARUS/NuMI_Nue/spine_anaplot_tools/spineplot/systematic.py:204: RuntimeWarning: invalid value encountered in scalar divide
#   self._std /= histogram.sum()
# 1246 <TBranchElement 'GENIEReWeight_SBN_v1_multisim_ZExpAVariationResponse' at 0x0003120b0e80>
# 1246 <TBranchElement 'GENIEReWeight_SBN_v1_multisim_RPA_CCQE' at 0x0003120b3fa0>
# 1246 <TBranchElement 'GENIEReWeight_SBN_v1_multisim_CoulombCCQE' at 0x0003120b3c40>
# 1246 <TBranchElement 'GENIEReWeight_SBN_v1_multisim_NormCCMEC' at 0x0003120b22f0>
# 1246 <TBranchElement 'GENIEReWeight_SBN_v1_multisim_NormNCMEC' at 0x0003121c61d0>
# 1246 <TBranchElement 'GENIEReWeight_SBN_v1_multisim_NCELVariationResponse' at 0x0003121c4130>
# 1246 <TBranchElement 'GENIEReWeight_SBN_v1_multisim_CCRESVariationResponse' at 0x0003121c58d0>
# 1246 <TBranchElement 'GENIEReWeight_SBN_v1_multisim_NCRESVariationResponse' at 0x0003121c6aa0>
# 1246 <TBranchElement 'GENIEReWeight_SBN_v1_multisim_NonRESBGvpCC1pi' at 0x0003121c5540>
# 1246 <TBranchElement 'GENIEReWeight_SBN_v1_multisim_NonRESBGvpCC2pi' at 0x000310dd1780>
# 1246 <TBranchElement 'GENIEReWeight_SBN_v1_multisim_NonRESBGvpNC1pi' at 0x000310dd2aa0>
# 1246 <TBranchElement 'GENIEReWeight_SBN_v1_multisim_NonRESBGvpNC2pi' at 0x000310dd3f10>
# 1246 <TBranchElement 'GENIEReWeight_SBN_v1_multisim_NonRESBGvnCC1pi' at 0x000310dd1270>
# 1246 <TBranchElement 'GENIEReWeight_SBN_v1_multisim_NonRESBGvnCC2pi' at 0x000310dd2200>
# 1246 <TBranchElement 'GENIEReWeight_SBN_v1_multisim_NonRESBGvnNC1pi' at 0x000310dd0970>
# 1246 <TBranchElement 'GENIEReWeight_SBN_v1_multisim_NonRESBGvnNC2pi' at 0x000310dd3460>
# 1246 <TBranchElement 'GENIEReWeight_SBN_v1_multisim_NonRESBGvbarpCC1pi' at 0x0003121a91e0>
# 1246 <TBranchElement 'GENIEReWeight_SBN_v1_multisim_NonRESBGvbarpCC2pi' at 0x0003121aaaa0>
# 1246 <TBranchElement 'GENIEReWeight_SBN_v1_multisim_NonRESBGvbarpNC1pi' at 0x0003121a98d0>
# 1246 <TBranchElement 'GENIEReWeight_SBN_v1_multisim_NonRESBGvbarpNC2pi' at 0x0003121aa560>
# 1246 <TBranchElement 'GENIEReWeight_SBN_v1_multisim_NonRESBGvbarnCC1pi' at 0x0003121abc40>
# 1246 <TBranchElement 'GENIEReWeight_SBN_v1_multisim_NonRESBGvbarnCC2pi' at 0x0003121a8040>
# 1246 <TBranchElement 'GENIEReWeight_SBN_v1_multisim_NonRESBGvbarnNC1pi' at 0x0003112cddb0>
# 1246 <TBranchElement 'GENIEReWeight_SBN_v1_multisim_NonRESBGvbarnNC2pi' at 0x0003112cd930>
# 1246 <TBranchElement 'GENIEReWeight_SBN_v1_multisim_RDecBR1gamma' at 0x0003112cfb20>
# 1246 <TBranchElement 'GENIEReWeight_SBN_v1_multisim_RDecBR1eta' at 0x0003112ced10>
# 1246 <TBranchElement 'GENIEReWeight_SBN_v1_multisim_COHVariationResponse' at 0x0003112cde40>
# 1246 <TBranchElement 'GENIEReWeight_SBN_v1_multisim_DISBYVariationResponse' at 0x0003112ccbe0>
# 1246 <TBranchElement 'GENIEReWeight_SBN_v1_multisim_FSI_pi_VariationResponse' at 0x0003112cd4b0>
# 1246 <TBranchElement 'GENIEReWeight_SBN_v1_multisim_FSI_N_VariationResponse' at 0x0003104a1cf0>
# 1246 <TBranchElement 'MINERvAE2p2h_SBN_v1_E2p2h_A_nu' at 0x0003104a1ff0>
# 1246 <TBranchElement 'MINERvAE2p2h_SBN_v1_E2p2h_B_nu' at 0x0003104a2500>
# 1246 <TBranchElement 'MINERvAE2p2h_SBN_v1_E2p2h_A_nubar' at 0x0003104a0130>
# 1246 <TBranchElement 'MINERvAE2p2h_SBN_v1_E2p2h_B_nubar' at 0x0003104a0fd0>
# 1246 <TBranchElement 'MINERvAg0q3Weighting_SBN_v1_Mnv202hGaussEnhancement' at 0x0003104a0520>
# 1246 <TBranchElement 'MiscInteractionSysts_SBN_v1_C12ToAr40_2p2hScaling_nu' at 0x00031121c280>
# 1246 <TBranchElement 'MiscInteractionSysts_SBN_v1_C12ToAr40_2p2hScaling_nubar' at 0x00031121c850>
# 1246 <TBranchElement 'MiscInteractionSysts_SBN_v1_nuenuebar_xsec_ratio' at 0x00031121dbd0>
# 1246 <TBranchElement 'MiscInteractionSysts_SBN_v1_nuenumu_xsec_ratio' at 0x00031121df00>
# 1246 <TBranchElement 'MiscInteractionSysts_SBN_v1_SPPLowQ2Suppression' at 0x00031121f280>
# 1246 <TBranchElement 'NOvAStyleNonResPionNorm_SBN_v1_NR_nu_n_CC_2Pi' at 0x00031121ff70>
# 1246 <TBranchElement 'NOvAStyleNonResPionNorm_SBN_v1_NR_nu_n_CC_3Pi' at 0x000310ddaa40>
# 1246 <TBranchElement 'NOvAStyleNonResPionNorm_SBN_v1_NR_nu_p_CC_2Pi' at 0x000310dd91b0>
# 1246 <TBranchElement 'NOvAStyleNonResPionNorm_SBN_v1_NR_nu_p_CC_3Pi' at 0x000310dd9750>
# 1246 <TBranchElement 'NOvAStyleNonResPionNorm_SBN_v1_NR_nu_np_CC_1Pi' at 0x000310dda110>
# 1246 <TBranchElement 'NOvAStyleNonResPionNorm_SBN_v1_NR_nu_n_NC_1Pi' at 0x0003096459c0>
# 1246 <TBranchElement 'NOvAStyleNonResPionNorm_SBN_v1_NR_nu_n_NC_2Pi' at 0x000309644790>
# 1246 <TBranchElement 'NOvAStyleNonResPionNorm_SBN_v1_NR_nu_n_NC_3Pi' at 0x000309647ac0>
# 1246 <TBranchElement 'NOvAStyleNonResPionNorm_SBN_v1_NR_nu_p_NC_1Pi' at 0x0003096443a0>
# 1246 <TBranchElement 'NOvAStyleNonResPionNorm_SBN_v1_NR_nu_p_NC_2Pi' at 0x000309645060>
# 1246 <TBranchElement 'NOvAStyleNonResPionNorm_SBN_v1_NR_nu_p_NC_3Pi' at 0x000309645a80>
# 1246 <TBranchElement 'NOvAStyleNonResPionNorm_SBN_v1_NR_nubar_n_CC_1Pi' at 0x00012d5d8580>
# 1246 <TBranchElement 'NOvAStyleNonResPionNorm_SBN_v1_NR_nubar_n_CC_2Pi' at 0x00012d5da920>
# 1246 <TBranchElement 'NOvAStyleNonResPionNorm_SBN_v1_NR_nubar_n_CC_3Pi' at 0x00012d5d80a0>
# 1246 <TBranchElement 'NOvAStyleNonResPionNorm_SBN_v1_NR_nubar_p_CC_1Pi' at 0x00012d5d8e20>
# 1246 <TBranchElement 'NOvAStyleNonResPionNorm_SBN_v1_NR_nubar_p_CC_2Pi' at 0x00012d5d9cc0>
# 1246 <TBranchElement 'NOvAStyleNonResPionNorm_SBN_v1_NR_nubar_p_CC_3Pi' at 0x00012d5da500>
# 1246 <TBranchElement 'NOvAStyleNonResPionNorm_SBN_v1_NR_nubar_n_NC_1Pi' at 0x00012d5daf80>
# 1246 <TBranchElement 'NOvAStyleNonResPionNorm_SBN_v1_NR_nubar_n_NC_2Pi' at 0x00014fb3a080>
# 1246 <TBranchElement 'NOvAStyleNonResPionNorm_SBN_v1_NR_nubar_n_NC_3Pi' at 0x00014fb3a3e0>
# 1246 <TBranchElement 'NOvAStyleNonResPionNorm_SBN_v1_NR_nubar_p_NC_1Pi' at 0x00014fb3abf0>
# 1246 <TBranchElement 'NOvAStyleNonResPionNorm_SBN_v1_NR_nubar_p_NC_2Pi' at 0x00014fb3a110>
# 1246 <TBranchElement 'NOvAStyleNonResPionNorm_SBN_v1_NR_nubar_p_NC_3Pi' at 0x00014fb3a1d0>
# 1246 <TBranchElement 'expskin_Flux' at 0x00012d5c0790>
# 1246 <TBranchElement 'horncurrent_Flux' at 0x00012d5c2c80>
# 1246 <TBranchElement 'kminus_Flux' at 0x00012d5c2080>
# 1246 <TBranchElement 'kplus_Flux' at 0x00012d5c28f0>
# 1246 <TBranchElement 'kzero_Flux' at 0x00012d5c1ae0>
# 1246 <TBranchElement 'nucleoninexsec_Flux' at 0x00012d5c0b80>
# 1246 <TBranchElement 'nucleonqexsec_Flux' at 0x00012d5c3550>
# 1246 <TBranchElement 'nucleontotxsec_Flux' at 0x00012d535cc0>
# 1246 <TBranchElement 'piminus_Flux' at 0x00012d536710>
# 1246 <TBranchElement 'pioninexsec_Flux' at 0x00012d536e00>
# 1246 <TBranchElement 'pionqexsec_Flux' at 0x00012d537b50>
# 1246 <TBranchElement 'piontotxsec_Flux' at 0x00012d535030>
# 1246 <TBranchElement 'piplus_Flux' at 0x00012d534460>
# Setting weight for onbeam to 1.00e+00
# Setting weight for offbeam to 9.22e-01
# Setting weight for mc_nu to 2.07e-01
# Setting weight for mc_cos to 2.07e-01
# Figure: {'show_component_number': True, 'show_component_percentage': True, 'invert_stack_order': True, 'draw_error': 'flux_xsec'} 0
# flux_xsec
# Figure: {'show_component_number': True, 'show_component_percentage': True, 'invert_stack_order': True, 'draw_error': 'flux_xsec'} 0
# flux_xsec
# Figure: {'show_component_number': True, 'show_component_percentage': True, 'invert_stack_order': True, 'draw_error': 'flux_xsec'} 0
# flux_xsec
# Figure: {'show_component_number': True, 'show_component_percentage': True, 'invert_stack_order': True, 'draw_error': 'flux_xsec'} 0
# flux_xsec
# Figure: {'show_component_number': True, 'show_component_percentage': True, 'invert_stack_order': True, 'draw_error': 'flux_xsec'} 0
# flux_xsec
# Figure: {'show_component_number': True, 'show_component_percentage': True, 'invert_stack_order': True, 'draw_error': 'flux_xsec'} 0
# flux_xsec
# Figure: {'show_component_number': True, 'show_component_percentage': True, 'invert_stack_order': True, 'draw_error': 'flux_xsec'} 0
# flux_xsec
# Figure: {'show_component_number': True, 'show_component_percentage': True, 'invert_stack_order': True, 'draw_error': 'flux_xsec'} 0
# flux_xsec
# Figure: {'show_component_number': True, 'show_component_percentage': True, 'invert_stack_order': True, 'draw_error': 'flux_xsec'} 0
# flux_xsec
# Figure: {'show_component_number': True, 'show_component_percentage': True, 'invert_stack_order': True, 'draw_error': 'flux_xsec'} 0
# flux_xsec
# Figure: {'show_component_number': True, 'show_component_percentage': True, 'invert_stack_order': True, 'draw_error': 'flux_xsec'} 0
# flux_xsec
# Figure: {'show_component_number': True, 'show_component_percentage': True, 'invert_stack_order': True, 'draw_error': 'flux_xsec'} 0
# flux_xsec
# Figure: {'show_component_number': True, 'show_component_percentage': True, 'invert_stack_order': True, 'draw_error': 'flux_xsec'} 0
# flux_xsec
# Figure: {'show_component_number': True, 'show_component_percentage': True, 'invert_stack_order': True, 'draw_error': 'flux_xsec'} 0
# flux_xsec
