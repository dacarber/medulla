# %%
import toml
from analysis import Analysis
#from analysis_syst import Analysis

# %%
cfg = """
[[this_includes]]
file = 'configurations/analyses/icarus/nue2025_icarus.toml'

[[this_includes]]
file = 'configurations/common/styles.toml'

[samples]
[samples.onbeam]
key = "onbeam"
exposure_type = "pot"
override_category = -100
trees = ['SelectedNu_PhaseCuts',]
#presel = "flash_time > -1.3 and flash_time < 0.5"
[samples.offbeam]
key = "offbeam"
exposure_type = "Livetime"
override_category = -1
trees = ['SelectedCos_PhaseCuts',]
#print_sys = true
[samples.mc_nu]
key = "mc"
exposure_type = "pot"
trees = ['SelectedNu_Cuts']
presel = 'matches_baseline == 1'
systematics = ['multisimTree','multisigmaTree']
print_sys = true
[samples.mc_cos]
key = "mc"
exposure_type = "pot"
trees = ['SelectedCos_PhaseCuts']
#presel = "flash_time > 0.2 and flash_time < 2.0"
#presel = 'matches_baseline == 1'
#systematics = ['multisigmaTree']
#[samples.mc]
#key = "mc"
#exposure_type = "pot"
#trees = ['SelectedNu_Cuts','SelectedCos_PhaseCuts']



[output]
path = '/Users/danielcarber/Documents/ICARUS/NuMI_Nue/Plots'

[[systematic_recipe]]
name = 'flux'
label = 'Flux Systematics'
#pattern = '_Flux'
pattern = '\\b\\w*_Flux\\b'

[[systematic_recipe]]
name = 'xsec'
label = 'Interaction Systematics'
pattern = '\\bGENIEReWeight_SBN_v1_multisigma_\\w+\\b'
#pattern = 'GENIEReWeight_SBN_v1_multisim'


[[systematic_recipe]]
name = 'stats'
label = 'Statistical Uncertainty'
#pattern = 'mc_statistical'
pattern = '(mc_nu|mc_cos)_statistical'
#pattern = '(mc|offbeam)_statistical'

#[[systematic_recipe]]
#name = 'offbeam_stats'
#label = 'Statistical Uncertainty'
#pattern = 'mc_statistical'
#pattern = '(mc_nu|mc_cos|offbeam)_statistical'
#pattern = '(offbeam)_statistical'

#[[systematic_recipe]]
#name = 'MC_stats'
#label = 'Statistical Uncertainty'
#pattern = 'mc_statistical'
#pattern = '(mc_nu|mc_cos)_statistical'
#pattern = '(offbeam)_statistical'

[[systematic_recipe]]
name = 'flux_xsec'
label = 'Flux + Interaction Uncertainty'
pattern = '(flux|xsec|stats)'
                
#[[systematic_recipe]]
#name = 'all'
#label = 'Total MC Uncertainty'
#pattern = '(flux|xsec|stats)'
#pattern = '(detsys|flux|xsec|stats)'


[analysis]
ordinate_sample = 'onbeam'
category_branch = 'category_topology'
category_assignment = [[0,1], [2,3,4,6], [5], [7],[8],[9],[11,-1], [-100]]
category_labels = ['1eNp', 'Other CC $\\nu_e$', 'NC $\\nu$', '$\\nu_\\mu$ CC','OOFVS','Other','Cosmic', 'Data']
category_colors = ['C0', 'C1', 'C3', 'C4', 'C5','C6','C7','black']
category_types = ['histogram', 'histogram', 'histogram', 'histogram', 'histogram','histogram', 'histogram', 'scatter']


[[figure]]
name = 'reco_electron_energy'
type = 'SimpleFigure'
#artists = [{'type' = 'SpineSpectra1D', 'variable' = 'reco_electron_energy','yrange' = [70, 3000],'draw_kwargs' = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = true, 'draw_error' = 'flux_xsec'}},]
style = 'selected_icarus'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_electron_energy'
#yrange = [0, 1000]
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = true,'draw_error' = 'flux_xsec','normalize' = true }#

[[figure]]
name = 'reco_visible_energy'
type = 'SimpleFigure'
#artists = [{'type' = 'SpineSpectra1D', 'variable' = 'reco_electron_energy','yrange' = [70, 3000],'draw_kwargs' = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = true, 'draw_error' = 'flux_xsec'}},]
style = 'selected_sbnd'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_visible_energy'
#yrange = [0, 1000]
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = true}#, 'draw_error' = 'flux_xsec'


[[figure]]
name = 'reco_electron_pT_mag'
type = 'SimpleFigure'
#artists = [{'type' = 'SpineSpectra1D', 'variable' = 'reco_electron_pT_mag'},]
style = 'selected_icarus'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_electron_pT_mag'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = true, 'draw_error' = 'flux_xsec'}

#[[figure]]
#name = 'reco_electron_conv_dist'
#type = 'SimpleFigure'
#artists = [{'type' = 'SpineSpectra1D', 'variable' = 'reco_electron_conv_dist'},]
#style = 'selected_icarus'
#[[figure.artists]]
#type = 'SpineSpectra1D'
#variable = 'reco_electron_conv_dist'
#draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = true, 'draw_error' = 'flux_xsec'}

[[figure]]
name = 'reco_electron_axial_spread'
type = 'SimpleFigure'
#artists = [{'type' = 'SpineSpectra1D', 'variable' = 'reco_electron_axial_spread'},]
style = 'selected_icarus'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_electron_axial_spread'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = true, 'draw_error' = 'flux_xsec'}

[[figure]]
name = 'reco_electron_dir_spread'
type = 'SimpleFigure'
#artists = [{'type' = 'SpineSpectra1D', 'variable' = 'reco_electron_dir_spread'},]
style = 'selected_icarus'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_electron_dir_spread'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = true, 'draw_error' = 'flux_xsec'}

[[figure]]
name = 'reco_proton_softmax'
type = 'SimpleFigure'
#artists = [{'type' = 'SpineSpectra1D', 'variable' = 'reco_proton_softmax'},]
style = 'selected_icarus'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_proton_softmax'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = true, 'draw_error' = 'flux_xsec'}
[[figure]]
name = 'reco_electron_softmax'
type = 'SimpleFigure'
#artists = [{'type' = 'SpineSpectra1D', 'variable' = 'reco_electron_softmax'},]
style = 'selected_icarus'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_electron_softmax'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = true, 'draw_error' = 'flux_xsec'}

[[figure]]
name = 'reco_electron_dedx'
type = 'SimpleFigure'
#artists = [{'type' = 'SpineSpectra1D', 'variable' = 'reco_electron_dedx'},]
style = 'selected_icarus'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_electron_dedx'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = true, 'draw_error' = 'flux_xsec'}

[[figure]]
name = 'reco_opening_angle'
type = 'SimpleFigure'
#artists = [{'type' = 'SpineSpectra1D', 'variable' = 'reco_opening_angle'},]
style = 'selected_icarus'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_opening_angle'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = true, 'draw_error' = 'flux_xsec'}

[[figure]]
name = 'reco_dalphaT'
type = 'SimpleFigure'
#artists = [{'type' = 'SpineSpectra1D', 'variable' = 'reco_dalphaT'},]
style = 'selected_icarus'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_dalphaT'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = true, 'draw_error' = 'flux_xsec'}

[[figure]]
name = 'reco_dphiT'
type = 'SimpleFigure'
#artists = [{'type' = 'SpineSpectra1D', 'variable' = 'reco_dphiT'},]
style = 'selected_icarus'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_dphiT'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = true, 'draw_error' = 'flux_xsec'}

[[figure]]
name = 'reco_proton_energy'
type = 'SimpleFigure'
#artists = [{'type' = 'SpineSpectra1D', 'variable' = 'reco_proton_energy'},]
style = 'selected_icarus'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_proton_energy'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = true, 'draw_error' = 'flux_xsec'}
[[figure]]
name = 'reco_dpT'
type = 'SimpleFigure'
#artists = [{'type' = 'SpineSpectra1D', 'variable' = 'reco_dpT'},]
style = 'selected_icarus'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_dpT'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = true}#, 'draw_error' = 'flux_xsec'

[[figure]]
name = 'reco_electron_polar'
type = 'SimpleFigure'
#artists = [{'type' = 'SpineSpectra1D', 'variable' = 'reco_electron_polar'},]
style = 'selected_icarus'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_electron_polar'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = true}#, 'draw_error' = 'flux_xsec'


#[[figure]]
#name = 'reco_dpT_lp'
#type = 'SimpleFigure'
#artists = [{'type' = 'SpineSpectra1D', 'variable' = 'reco_dpT_lp'},]
#style = 'selected_icarus'
#[[figure.artists]]
#type = 'SpineSpectra1D'
#variable = 'reco_dpT_lp'
#draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = true}#, 'draw_error' = 'flux_xsec'

#[[figure]]
#name = 'true_dpT'
#type = 'SimpleFigure'
#artists = [{'type' = 'SpineSpectra1D', 'variable' = 'true_dpT'},]
#style = 'selected_icarus'
#[[figure.artists]]
#type = 'SpineSpectra1D'
#variable = 'true_dpT'
#draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = true}#, 'draw_error' = 'flux_xsec'

#[[figure]]
#name = 'true_dpT_lp'
#type = 'SimpleFigure'
#artists = [{'type' = 'SpineSpectra1D', 'variable' = 'true_dpT_lp'},]
#style = 'selected_icarus'
#[[figure.artists]]
#type = 'SpineSpectra1D'
#variable = 'true_dpT_lp'
#draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = true}#, 'draw_error' = 'flux_xsec'

"""
# Write the string to a file
with open('cfg.toml', 'w') as f:
    f.write(cfg)

file = '/Users/danielcarber/Documents/ICARUS/full_syst.root'

analysis = Analysis('cfg.toml', file)
analysis.override_exposure('onbeam',1,'pot')
analysis.run(close_figs=False)
# Out:
# /Users/danielcarber/Documents/ICARUS/NuMI_Nue/develop_branches/medulla_NuMI_plotting/spineplot/systematic.py:203: RuntimeWarning: invalid value encountered in scalar divide
#   self._std /= histogram.sum()
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 289
#     285     f.write(cfg)
#     287 file = '/Users/danielcarber/Documents/ICARUS/full_syst.root'
# --> 289 analysis = Analysis('cfg.toml', file)
#     290 analysis.override_exposure('onbeam',1,'pot')
#     291 analysis.run(close_figs=False)
#
# File ~/Documents/ICARUS/NuMI_Nue/develop_branches/medulla_NuMI_plotting/spineplot/analysis.py:94, in Analysis.__init__(self, toml_path, rf_path)
#      92     for v in self._variables.values():
#      93         s.register_variable(v, self._categories)
# ---> 94     s.process_systematics(recipes)
#      96 # Load the artists table
#      97 if 'figure' not in self._config.keys():
#
# File ~/Documents/ICARUS/NuMI_Nue/develop_branches/medulla_NuMI_plotting/spineplot/sample.py:245, in Sample.process_systematics(self, recipes)
#     231 """
#     232 Processes the systematic uncertainties for the sample.
#     233
#    (...)
#     242 None.
#     243 """
#     244 for syst in self._systematics.values():
# --> 245     syst.process(self, self._presel_mask)
#     247 # Each recipe has a name, which is used to identify the
#     248 # combination of systematic uncertainties, and a pattern,
#     249 # which is used to build a list of Systematic objects to
#     250 # combine.
#     251 for recipe in recipes:
#
# File ~/Documents/ICARUS/NuMI_Nue/develop_branches/medulla_NuMI_plotting/spineplot/systematic.py:134, in Systematic.process(self, sample, mask, nuniv)
#     130 # Check that the handle is valid. This is the "usual" case
#     131 # where the systematic weights are stored in a TTree.
#     132 if self._handle is not None:
#     133     # Read the weights from the TTree
# --> 134     weights_array = np.stack(self._handle.array(library='np'))[mask, :]
#     136     if weights_array.shape[1] == 7:
#     137         # Set the "sigma" levels corresponding to each weight in the
#     138         # array.
#     139         sigma_levels = np.linspace(-3, 3, 7)
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages/uproot/behaviors/TBranch.py:1817, in TBranch.array(self, interpretation, entry_start, entry_stop, decompression_executor, interpretation_executor, array_cache, library, ak_add_doc)
#    1814                 ranges_or_baskets.append((branch, basket_num, range_or_basket))
#    1816 interp_options = {"ak_add_doc": ak_add_doc}
# -> 1817 _ranges_or_baskets_to_arrays(
#    1818     self,
#    1819     ranges_or_baskets,
#    1820     branchid_interpretation,
#    1821     entry_start,
#    1822     entry_stop,
#    1823     decompression_executor,
#    1824     interpretation_executor,
#    1825     library,
#    1826     arrays,
#    1827     False,
#    1828     interp_options,
#    1829 )
#    1831 _fix_asgrouped(
#    1832     arrays,
#    1833     expression_context,
#    (...)
#    1837     ak_add_doc,
#    1838 )
#    1840 if array_cache is not None:
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages/uproot/behaviors/TBranch.py:3138, in _ranges_or_baskets_to_arrays(hasbranches, ranges_or_baskets, branchid_interpretation, entry_start, entry_stop, decompression_executor, interpretation_executor, library, arrays, update_ranges_or_baskets, interp_options)
#    3136 if isinstance(obj, uproot.source.chunk.Chunk):
#    3137     args = range_args[(obj.start, obj.stop)]
# -> 3138     decompression_executor.submit(chunk_to_basket, obj, *args)
#    3140 elif isinstance(obj, uproot.models.TBasket.Model_TBasket):
#    3141     interpretation_executor.submit(basket_to_array, obj)
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages/uproot/source/futures.py:73, in TrivialExecutor.submit(self, task, *args)
#      69 def submit(self, task, *args):
#      70     """
#      71     Immediately runs ``task(*args)``.
#      72     """
# ---> 73     return TrivialFuture(task(*args))
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages/uproot/behaviors/TBranch.py:3060, in _ranges_or_baskets_to_arrays.<locals>.chunk_to_basket(chunk, branch, basket_num)
#    3058 try:
#    3059     cursor = uproot.source.cursor.Cursor(chunk.start)
# -> 3060     basket = uproot.models.TBasket.Model_TBasket.read(
#    3061         chunk,
#    3062         cursor,
#    3063         {"basket_num": basket_num},
#    3064         hasbranches._file,
#    3065         hasbranches._file,
#    3066         branch,
#    3067     )
#    3068     original_index = range_original_index[(chunk.start, chunk.stop)]
#    3069     if update_ranges_or_baskets:
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages/uproot/model.py:860, in Model.read(cls, chunk, cursor, context, file, selffile, parent, concrete)
#     851     if forth_stash is not None:
#     852         forth_obj.add_node(
#     853             "model828",
#     854             forth_stash.get_attrs(),
#    (...)
#     857             {},
#     858         )
# --> 860     self.read_members(chunk, cursor, context, file)
#     861     self.hook_after_read_members(
#     862         chunk=chunk, cursor=cursor, context=context, file=file
#     863     )
#     865 self.check_numbytes(chunk, cursor, context)
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages/uproot/models/TBasket.py:291, in Model_TBasket.read_members(self, chunk, cursor, context, file)
#     289 if compressed_bytes != uncompressed_bytes:
#     290     self._block_compression_info = []
# --> 291     uncompressed = uproot.compression.decompress(
#     292         chunk,
#     293         cursor,
#     294         {},
#     295         compressed_bytes,
#     296         uncompressed_bytes,
#     297         self._block_compression_info,
#     298     )
#     299     self._block_compression_info = tuple(self._block_compression_info)
#     300     self._raw_data = uncompressed.get(
#     301         0,
#     302         uncompressed_bytes,
#     303         uproot.source.cursor.Cursor(0),
#     304         context,
#     305     )
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages/uproot/compression.py:415, in decompress(chunk, cursor, context, compressed_bytes, uncompressed_bytes, block_info)
#     410 if block_info is not None:
#     411     block_info.append(
#     412         (decompressor.name, block_compressed_bytes, block_uncompressed_bytes)
#     413     )
# --> 415 uncompressed_bytestring = decompressor.decompress(
#     416     data, block_uncompressed_bytes
#     417 )
#     419 if len(uncompressed_bytestring) != block_uncompressed_bytes:
#     420     raise ValueError(
#     421         """after successfully decompressing {} blocks, a block of """
#     422         """compressed size {} decompressed to {} bytes, but the """
#    (...)
#     430         )
#     431     )
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages/uproot/compression.py:94, in _DecompressZLIB.decompress(self, data, uncompressed_bytes)
#      91 def decompress(self, data, uncompressed_bytes=None):
#      92     import zlib
# ---> 94     return zlib.decompress(data)
#
# KeyboardInterrupt:
