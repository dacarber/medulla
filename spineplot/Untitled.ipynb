# %%
import numpy as np
import matplotlib.pyplot as plt
import h5py
import importlib
import pandas as pd
from datetime import datetime
from tqdm import tqdm
from plotly.subplots import make_subplots
from plotly import tools
import plotly.offline as pyo
import plotly.express as px
import plotly.io as pio
import plotly.graph_objects as go
import glob
from scipy import stats
import uproot
from ROOT import TFile, TEfficiency, TH1D, TGraphAsymmErrors, RDataFrame, TCanvas

# %%
file = uproot.open("/Users/danielcarber/Documents/ICARUS/testtest.root")
print(file.keys())
# Out:
# ['events;1', 'events/mc;1', 'events/mc/POT;3', 'events/mc/POT;2', 'events/mc/POT;1', 'events/mc/Livetime;3', 'events/mc/Livetime;2', 'events/mc/Livetime;1', 'events/mc/SelectedNu_Cuts;1', 'events/mc/SelectedCos_PhaseCuts;1', 'events/mc/Purity_PhaseCuts;1']

# %%
Nu_Purity = file['events/mc/SelectedNu_Cuts;1']
Cosmic_Purity = file['events/mc/SelectedCos_PhaseCuts;1']
Nu_Purity=Nu_Purity.arrays(library='pd')
Cosmic_Purity = Cosmic_Purity.arrays(library='pd')
print(Nu_Purity)
print(Cosmic_Purity)
# Out:
#         baseline  category  category_topology  interaction_mode  nu_id  \
# 0     805.780701       3.0                8.0               1.0    0.0
# 1     798.502136       0.0                0.0              10.0    0.0
# 2     748.860535       0.0                0.0               0.0    0.0
# 3     770.191528       0.0                0.0               0.0    0.0
# 4     785.730835       0.0                0.0               2.0    0.0
# ...          ...       ...                ...               ...    ...
# 1256  790.018127       0.0                0.0               0.0    0.0
# 1257  797.503540       2.0                1.0               0.0    0.0
# 1258  799.828064       4.0                3.0               1.0    0.0
# 1259  744.817200       2.0                1.0               1.0    0.0
# 1260  798.373718       0.0                0.0               0.0    0.0
#
#       reco_NuMI_azi  reco_NuMI_polar  reco_dalphaT     reco_dpT  reco_dphiT  \
# 0          0.101053         0.407746           NaN  1158.588955         NaN
# 1          0.103832         0.404506           NaN   586.696124         NaN
# 2          0.103163         0.411416           NaN   674.140796         NaN
# 3          0.106431         0.402547           NaN  1835.379194         NaN
# 4          0.103832         0.404506           NaN   586.696124         NaN
# ...             ...              ...           ...          ...         ...
# 1256       0.105065         0.407711           NaN   805.592254         NaN
# 1257       0.109696         0.405967      3.141593   903.960454    3.141593
# 1258       0.110488         0.401454           NaN   635.162965         NaN
# 1259       0.107528         0.405131      3.141593   898.346228    3.141593
# 1260       0.106678         0.401959      3.141593   847.028864    3.141593
#
#       ...  true_proton_NuMI_angle  true_proton_energy  true_proton_pT_mag  \
# 0     ...                2.118547                -1.0          249.973447
# 1     ...                0.713690                -1.0          317.844411
# 2     ...                0.396132                -1.0          352.386517
# 3     ...                0.948675                -1.0          885.859399
# 4     ...                0.713690                -1.0          317.844411
# ...   ...                     ...                 ...                 ...
# 1256  ...                0.772966                -1.0          397.911225
# 1257  ...                0.713780                -1.0          500.479296
# 1258  ...                0.176242                -1.0          217.245910
# 1259  ...                0.536494                -1.0          422.140567
# 1260  ...                1.176062                -1.0          416.727932
#
#       true_vertex_x  true_vertex_y  true_vertex_z  true_visible_energy  Run  \
# 0        268.728760    -161.927490     552.224304             0.872887    1
# 1       -202.765625    -102.336662     164.036316             2.055268    1
# 2        237.069397     -77.898232    -210.495667             0.704446    1
# 3       -265.433075     -26.548813     443.049744             2.147723    1
# 4       -202.765625    -102.336662     164.036316             2.055268    1
# ...             ...            ...            ...                  ...  ...
# 1256    -139.287598     -56.095993    -327.954651             0.765106    1
# 1257    -143.831543      90.263687      52.877197             0.651111    1
# 1258    -211.845657     109.622787     824.939758             1.308235    1
# 1259    -319.868774       3.119675    -204.773926             0.874497    1
# 1260    -162.079391      -7.557800     801.335632             1.347323    1
#
#       Subrun  Evt
# 0          0    2
# 1          0   14
# 2          0   17
# 3          0   19
# 4          0   14
# ...      ...  ...
# 1256       0    4
# 1257       0   10
# 1258       0   16
# 1259       0    1
# 1260       0    7
#
# [1261 rows x 50 columns]
#    baseline  category  category_topology  interaction_mode  nu_id  \
# 0       NaN       7.0                9.0               NaN   -1.0
# 1       NaN       7.0                9.0               NaN   -1.0
# 2       NaN       7.0                9.0               NaN   -1.0
# 3       NaN       7.0                9.0               NaN   -1.0
#
#    reco_NuMI_azi  reco_NuMI_polar  reco_dalphaT     reco_dpT  reco_dphiT  ...  \
# 0       0.101887         0.405483      3.141593   992.257642    3.141593  ...
# 1       0.108330         0.410395      3.141593  4069.360180    3.141593  ...
# 2       0.102123         0.414294      3.141593  1245.434867    3.141593  ...
# 3       0.104657         0.415316      3.141593   682.060796    3.141593  ...
#
#    true_proton_NuMI_angle  true_proton_energy  true_proton_pT_mag  \
# 0                1.696109                -1.0                 0.0
# 1                1.434478                -1.0                 0.0
# 2                1.575774                -1.0                 0.0
# 3                1.171512                -1.0                 0.0
#
#    true_vertex_x  true_vertex_y  true_vertex_z  true_visible_energy  Run  \
# 0    1170.746826    2000.000122     639.739197            30.008096    1
# 1    -219.904678    2000.000122    -139.882629             7.985718    1
# 2    1059.853149    2000.000122   -1142.632446            30.662463    1
# 3     201.561279    2000.000122   -2111.089600             0.000000    1
#
#    Subrun  Evt
# 0       0    2
# 1       0   12
# 2       0   16
# 3       0   10
#
# [4 rows x 50 columns]

# %%
mask  = (Nu_Purity['category_topology']==0) | (Nu_Purity['category_topology']==1)
print(mask)
print(sum(mask)/len(Nu_Purity))
# Out:
# 0       False
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 1256     True
# 1257     True
# 1258    False
# 1259     True
# 1260     True
# Name: category_topology, Length: 1261, dtype: bool
# 0.7985725614591594
