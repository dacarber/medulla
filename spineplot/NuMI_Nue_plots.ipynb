# %%
import toml
from analysis import Analysis

# %%
cfg = """
[[this_includes]]
file = 'configurations/analyses/icarus/nue2025_icarus.toml'

[[this_includes]]
file = 'configurations/common/styles.toml'

[samples]
[samples.mc]
key = "mc"
exposure_type = "pot"
trees = ['SelectedNu_Cuts','SelectedCos_PhaseCuts']



[output]
path = '/Users/danielcarber/Documents/ICARUS/NuMI_Nue/Plots'

[[systematic_recipe]]
name = 'flux'
label = 'Flux Systematics'
#pattern = '_Flux'
pattern = '\\b\\w*_Flux\\b'

[[systematic_recipe]]
name = 'xsec'
label = 'Interaction Systematics'
pattern = '\\bGENIEReWeight_SBN_v1_multisim_\\w+\\b'
#pattern = 'GENIEReWeight_SBN_v1_multisim'


[[systematic_recipe]]
name = 'stats'
label = 'Statistical Uncertainty'
#pattern = 'mc_statistical'
pattern = '(mc_nu|mc_cos|offbeam)_statistical'
#pattern = '(mc|offbeam)_statistical'

#[[systematic_recipe]]
#name = 'offbeam_stats'
#label = 'Statistical Uncertainty'
#pattern = 'mc_statistical'
#pattern = '(mc_nu|mc_cos|offbeam)_statistical'
#pattern = '(offbeam)_statistical'

#[[systematic_recipe]]
#name = 'MC_stats'
#label = 'Statistical Uncertainty'
#pattern = 'mc_statistical'
#pattern = '(mc_nu|mc_cos)_statistical'
#pattern = '(offbeam)_statistical'

[[systematic_recipe]]
name = 'flux_xsec'
label = 'Flux + Interaction Uncertainty'
pattern = '(flux|xsec|stats)'
                
#[[systematic_recipe]]
#name = 'all'
#label = 'Total MC Uncertainty'
#pattern = '(flux|xsec|stats)'
#pattern = '(detsys|flux|xsec|stats)'


[analysis]
ordinate_sample = 'mc'
category_branch = 'category_topology'
category_assignment = [[0,1], [2,3,4,6], [5], [7],[8],[9],[10,-1], [-100]]
category_labels = ['1eNp', 'Other CC $\\nu_e$', 'NC $\\nu$', '$\\nu_\\mu$ CC','Uncontained','Other','Cosmic', 'Run 2 Data']
category_colors = ['C0', 'C1', 'C3', 'C4', 'C5','C6','C7','black']
category_types = ['histogram', 'histogram', 'histogram', 'histogram', 'histogram','histogram', 'histogram', 'scatter']


[[figure]]
name = 'reco_electron_energy'
type = 'SimpleFigure'
artists = [{'type' = 'SpineSpectra1D', 'variable' = 'reco_electron_energy'},]
style = 'selected_icarus'

[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_electron_energy'
range = [70, 3000]
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = true}

[[figure]]
name = 'reco_electron_pT_mag'
type = 'SimpleFigure'
artists = [{'type' = 'SpineSpectra1D', 'variable' = 'reco_electron_pT_mag'},]
style = 'selected_icarus'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_electron_pT_mag'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = true, 'draw_error' = 'flux_xsec'}

[[figure]]
name = 'reco_electron_conv_dist'
type = 'SimpleFigure'
artists = [{'type' = 'SpineSpectra1D', 'variable' = 'reco_electron_conv_dist'},]
style = 'selected_icarus'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_electron_conv_dist'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = true, 'draw_error' = 'flux_xsec'}

[[figure]]
name = 'reco_electron_axial_spread'
type = 'SimpleFigure'
artists = [{'type' = 'SpineSpectra1D', 'variable' = 'reco_electron_axial_spread'},]
style = 'selected_icarus'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_electron_axial_spread'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = true, 'draw_error' = 'flux_xsec'}

[[figure]]
name = 'reco_electron_dir_spread'
type = 'SimpleFigure'
artists = [{'type' = 'SpineSpectra1D', 'variable' = 'reco_electron_dir_spread'},]
style = 'selected_icarus'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_electron_dir_spread'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = true, 'draw_error' = 'flux_xsec'}

[[figure]]
name = 'reco_proton_softmax'
type = 'SimpleFigure'
artists = [{'type' = 'SpineSpectra1D', 'variable' = 'reco_proton_softmax'},]
style = 'selected_icarus'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_proton_softmax'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = true, 'draw_error' = 'flux_xsec'}
[[figure]]
name = 'reco_dpT'
type = 'SimpleFigure'
artists = [{'type' = 'SpineSpectra1D', 'variable' = 'reco_dpT'},]
style = 'selected_icarus'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_dpT'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = true, 'draw_error' = 'flux_xsec'}
[[figure]]
name = 'reco_electron_softmax'
type = 'SimpleFigure'
artists = [{'type' = 'SpineSpectra1D', 'variable' = 'reco_electron_softmax'},]
style = 'selected_icarus'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_electron_softmax'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = true, 'draw_error' = 'flux_xsec'}

[[figure]]
name = 'reco_electron_dedx'
type = 'SimpleFigure'
artists = [{'type' = 'SpineSpectra1D', 'variable' = 'reco_electron_dedx'},]
style = 'selected_icarus'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_electron_dedx'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = true, 'draw_error' = 'flux_xsec'}

[[figure]]
name = 'reco_opening_angle'
type = 'SimpleFigure'
artists = [{'type' = 'SpineSpectra1D', 'variable' = 'reco_opening_angle'},]
style = 'selected_icarus'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_opening_angle'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = true, 'draw_error' = 'flux_xsec'}

[[figure]]
name = 'reco_dalphaT'
type = 'SimpleFigure'
artists = [{'type' = 'SpineSpectra1D', 'variable' = 'reco_dalphaT'},]
style = 'selected_icarus'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_dalphaT'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = true, 'draw_error' = 'flux_xsec'}

[[figure]]
name = 'reco_dphiT'
type = 'SimpleFigure'
artists = [{'type' = 'SpineSpectra1D', 'variable' = 'reco_dphiT'},]
style = 'selected_icarus'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_dphiT'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = true, 'draw_error' = 'flux_xsec'}

[[figure]]
name = 'reco_NuMI_polar'
type = 'SimpleFigure'
artists = [{'type' = 'SpineSpectra1D', 'variable' = 'reco_NuMI_polar'},]
style = 'selected_icarus'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_NuMI_polar'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = true, 'draw_error' = 'flux_xsec'}

[[figure]]
name = 'reco_NuMI_azi'
type = 'SimpleFigure'
artists = [{'type' = 'SpineSpectra1D', 'variable' = 'reco_NuMI_azi'},]
style = 'selected_icarus'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_NuMI_azi'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = true, 'draw_error' = 'flux_xsec'}

[[figure]]
name = 'reco_proton_energy'
type = 'SimpleFigure'
artists = [{'type' = 'SpineSpectra1D', 'variable' = 'reco_proton_energy'},]
style = 'selected_icarus'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_proton_energy'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = true, 'draw_error' = 'flux_xsec'}



"""
# Write the string to a file
with open('cfg.toml', 'w') as f:
    f.write(cfg)

file = '/Users/danielcarber/Documents/ICARUS/nue_mc.root'

analysis = Analysis('cfg.toml', file)
analysis.run(close_figs=False)
# Out:
# Setting weight for mc to 1.00e+00
# Figure: {'show_component_number': True, 'show_component_percentage': True, 'invert_stack_order': True, 'draw_error': None} 0
# None
# Figure: {'show_component_number': True, 'show_component_percentage': True, 'invert_stack_order': True, 'draw_error': 'flux_xsec'} 0
# flux_xsec
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 234
#     231 file = '/Users/danielcarber/Documents/ICARUS/nue_mc.root'
#     233 analysis = Analysis('cfg.toml', file)
# --> 234 analysis.run(close_figs=False)
#
# File ~/Documents/ICARUS/NuMI_Nue/spine_anaplot_tools/spineplot/analysis.py:244, in Analysis.run(self, close_figs)
#     242     os.makedirs(self._output_path)
#     243 for figname, figure in self._figures.items():
# --> 244     figure.create()
#     245     figure.figure.savefig(f"{self._output_path}/{figname}.png")
#     246     if close_figs:
#
# File ~/Documents/ICARUS/NuMI_Nue/spine_anaplot_tools/spineplot/figure.py:145, in SimpleFigure.create(self)
#     143 self._figure = plt.figure(figsize=self._figsize)
#     144 self._axs = [self._figure.add_subplot(),]
# --> 145 super().create()
#
# File ~/Documents/ICARUS/NuMI_Nue/spine_anaplot_tools/spineplot/figure.py:81, in SpineFigure.create(self)
#      79 for axi, ax in enumerate(self._axs):
#      80     print("Figure:",self._draw_kwargs[1],axi)
# ---> 81     self._artists[axi].draw(ax, **self._draw_kwargs[1], style=style)
#      82 self._figure.suptitle(self._title)
#
# File ~/Documents/ICARUS/NuMI_Nue/spine_anaplot_tools/spineplot/spectra1d.py:238, in SpineSpectra1D.draw(self, ax, style, show_component_number, show_component_percentage, invert_stack_order, fit_type, logx, logy, draw_error)
#     236     y = np.sum(reduce(data), axis=0)
#     237     xerr = [x / 2 for x in binwidths[0]]
# --> 238     yerr = np.sqrt(np.diag(cov))
#     239     draw_error_boxes(ax, x, y, xerr, yerr, facecolor='gray', edgecolor='none', alpha=0.5, hatch='///')
#     241 reduce = lambda x : [x[i] for i in scatter_mask]
#
# File <__array_function__ internals>:200, in diag(*args, **kwargs)
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.10/site-packages/numpy/lib/twodim_base.py:309, in diag(v, k)
#     307     return diagonal(v, k)
#     308 else:
# --> 309     raise ValueError("Input must be 1- or 2-d.")
#
# ValueError: Input must be 1- or 2-d.
